# %%
import pandas as pd

# Load the data
file_path = 'hotel_bookings.csv'
data = pd.read_csv(file_path)

# Filter top 7 countries with the most bookings
top_countries = data['country'].value_counts().head(7).index
filtered_data = data[data['country'].isin(top_countries)]

# Add one-hot encoded columns to classify the type of bookings
filtered_data['adult_only_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] == 0) & (filtered_data['babies'] == 0)).astype(int)
filtered_data['adult_children_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) & (filtered_data['babies'] == 0)).astype(int)
filtered_data['adult_baby_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] == 0) & (filtered_data['babies'] > 0)).astype(int)
filtered_data['all_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) & (filtered_data['babies'] > 0)).astype(int)
filtered_data['some_kind_of_kid'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) | (filtered_data['babies'] > 0)).astype(int)

# Group by country and calculate counts for each booking type
summary_df = filtered_data.groupby('country').agg(
    total_bookings=('country', 'size'),  # Number of bookings (rows per country)
    adult_only_booking=('adult_only_booking', 'sum'),
    adult_children_booking=('adult_children_booking', 'sum'),
    adult_baby_booking=('adult_baby_booking', 'sum'),
    all_booking=('all_booking', 'sum'),
    some_kind_of_kid=('some_kind_of_kid', 'sum'),
    city_hotel=('hotel', lambda x: (x == 'City Hotel').sum()),  # Count of City Hotel bookings
    resort_hotel=('hotel', lambda x: (x == 'Resort Hotel').sum()),  # Count of Resort Hotel bookings
    cancellations=('is_canceled', 'sum')  # Sum of cancellations per country
).reset_index()

summary_df


# summary_df
# Create the Portugal DataFrame
portugal_df = summary_df[summary_df['country'] == 'PRT']

# Create the DataFrame for the other countries
other_countries_df = summary_df[summary_df['country'] != 'PRT']

# Save the DataFrames if needed
portugal_df.to_csv('portugal_data.csv', index=False)
other_countries_df.to_csv('other_countries_data.csv', index=False)
# Out:
# /var/folders/_1/_rnshwnd0px1m82vsfm_3cg80000gn/T/ipykernel_47958/3581646826.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['adult_only_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] == 0) & (filtered_data['babies'] == 0)).astype(int)
# /var/folders/_1/_rnshwnd0px1m82vsfm_3cg80000gn/T/ipykernel_47958/3581646826.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['adult_children_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) & (filtered_data['babies'] == 0)).astype(int)
# /var/folders/_1/_rnshwnd0px1m82vsfm_3cg80000gn/T/ipykernel_47958/3581646826.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['adult_baby_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] == 0) & (filtered_data['babies'] > 0)).astype(int)
# /var/folders/_1/_rnshwnd0px1m82vsfm_3cg80000gn/T/ipykernel_47958/3581646826.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['all_booking'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) & (filtered_data['babies'] > 0)).astype(int)
# /var/folders/_1/_rnshwnd0px1m82vsfm_3cg80000gn/T/ipykernel_47958/3581646826.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['some_kind_of_kid'] = ((filtered_data['adults'] > 0) & (filtered_data['children'] > 0) | (filtered_data['babies'] > 0)).astype(int)

# %%
summary_df
# Out:
#   country  total_bookings  adult_only_booking  adult_children_booking  \
# 0     DEU            7287                6920                     333
# 1     ESP            8568                7473                     947
# 2     FRA           10415                9482                     817
# 3     GBR           12129               11209                     813
# 4     IRL            3375                3145                     201
# 5     ITA            3766                3420                     317
# 6     PRT           48590               45707                    2315
#
#    adult_baby_booking  all_booking  city_hotel  resort_hotel  cancellations
# 0                  16            2        6084          1203           1218
# 1                 105           21        4611          3957           2177
# 2                  61           16        8804          1611           1934
# 3                  72           11        5315          6814           2453
# 4                  20            4        1209          2166            832
# 5                  10            5        3307           459           1333
# 6                 324           90       30960         17630          27519

# %%
filtered_data[['adults', 'children', 'babies']].value_counts()
# Out:
# adults  children  babies
# 2       0.0       0         65151
# 1       0.0       0         18251
# 3       0.0       0          3891
# 2       1.0       0          2815
#         2.0       0          2208
#         0.0       1           582
# 3       1.0       0           358
# 1       1.0       0           196
# 0       0.0       0           146
# 2       1.0       1           116
# 0       2.0       0           109
# 1       2.0       0            96
# 4       0.0       0            47
# 2       3.0       0            36
# 3       2.0       0            29
# 2       2.0       1            24
#         0.0       2            10
# 0       3.0       0            10
# 3       0.0       1             8
# 26      0.0       0             5
# 1       0.0       1             5
# 2       1.0       2             3
# 0       2.0       1             3
# 27      0.0       0             2
# 20      0.0       0             2
# 5       0.0       0             2
# 4       1.0       0             2
# 1       1.0       1             2
# 3       1.0       1             2
# 0       1.0       0             2
# 1       3.0       0             2
#         2.0       1             2
# 2       10.0      0             1
# 4       0.0       1             1
# 2       0.0       10            1
# 6       0.0       0             1
# 10      0.0       0             1
# 1       0.0       9             1
# 40      0.0       0             1
# 50      0.0       0             1
# 55      0.0       0             1
# Name: count, dtype: int64

# %%
summary_df.to_csv('first_visualization.csv', index=False)
